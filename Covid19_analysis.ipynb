# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the dataset

# %%
covid_death_dataset = pd.read_csv("covid19_deaths_dataset.csv")

# %%
covid_death_dataset.head(10)
covid_death_dataset.shape
# Out:
# (266, 104)

# %%
covid_death_dataset.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20   ...     4/21/20  \
# 0        0        0        0        0        0        0   ...          36
# 1        0        0        0        0        0        0   ...          26
# 2        0        0        0        0        0        0   ...         392
# 3        0        0        0        0        0        0   ...          37
# 4        0        0        0        0        0        0   ...           2
# 5        0        0        0        0        0        0   ...           3
# 6        0        0        0        0        0        0   ...         147
# 7        0        0        0        0        0        0   ...          24
# 8        0        0        0        0        0        0   ...           3
# 9        0        0        0        0        0        0   ...          26
#
#    4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  \
# 0       40       42       43       47       50       57       58       60
# 1       27       27       27       27       28       28       30       30
# 2      402      407      415      419      425      432      437      444
# 3       37       37       40       40       40       40       41       42
# 4        2        2        2        2        2        2        2        2
# 5        3        3        3        3        3        3        3        3
# 6      152      165      176      185      192      197      207      214
# 7       24       24       27       28       28       29       30       30
# 8        3        3        3        3        3        3        3        3
# 9       26       31       33       33       34       34       39       40
#
#    4/30/20
# 0       64
# 1       31
# 2      450
# 3       42
# 4        2
# 5        3
# 6      218
# 7       32
# 8        3
# 9       41
#
# [10 rows x 104 columns]

# %%
del_col = ["Lat","Long"]

# %%
covid_death_dataset.drop(del_col, axis = 1,inplace=True)

# %%
covid_death_dataset.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20   ...     4/21/20  \
# 0        0        0        0        0        0        0   ...          36
# 1        0        0        0        0        0        0   ...          26
# 2        0        0        0        0        0        0   ...         392
# 3        0        0        0        0        0        0   ...          37
# 4        0        0        0        0        0        0   ...           2
# 5        0        0        0        0        0        0   ...           3
# 6        0        0        0        0        0        0   ...         147
# 7        0        0        0        0        0        0   ...          24
# 8        0        0        0        0        0        0   ...           3
# 9        0        0        0        0        0        0   ...          26
#
#    4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  \
# 0       40       42       43       47       50       57       58       60
# 1       27       27       27       27       28       28       30       30
# 2      402      407      415      419      425      432      437      444
# 3       37       37       40       40       40       40       41       42
# 4        2        2        2        2        2        2        2        2
# 5        3        3        3        3        3        3        3        3
# 6      152      165      176      185      192      197      207      214
# 7       24       24       27       28       28       29       30       30
# 8        3        3        3        3        3        3        3        3
# 9       26       31       33       33       34       34       39       40
#
#    4/30/20
# 0       64
# 1       31
# 2      450
# 3       42
# 4        2
# 5        3
# 6      218
# 7       32
# 8        3
# 9       41
#
# [10 rows x 102 columns]

# %%
death_aggregation = covid_death_dataset.groupby("Country/Region").sum()

# %%
death_aggregation.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        0        0
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20   ...     4/21/20  \
# Country/Region                                            ...
# Afghanistan                0        0        0        0   ...          36
# Albania                    0        0        0        0   ...          26
# Algeria                    0        0        0        0   ...         392
# Andorra                    0        0        0        0   ...          37
# Angola                     0        0        0        0   ...           2
# Antigua and Barbuda        0        0        0        0   ...           3
# Argentina                  0        0        0        0   ...         147
# Armenia                    0        0        0        0   ...          24
# Australia                  0        0        0        0   ...          67
# Austria                    0        0        0        0   ...         491
#
#                      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# Country/Region
# Afghanistan               40       42       43       47       50       57
# Albania                   27       27       27       27       28       28
# Algeria                  402      407      415      419      425      432
# Andorra                   37       37       40       40       40       40
# Angola                     2        2        2        2        2        2
# Antigua and Barbuda        3        3        3        3        3        3
# Argentina                152      165      176      185      192      197
# Armenia                   24       24       27       28       28       29
# Australia                 67       75       79       80       83       83
# Austria                  510      522      530      536      542      549
#
#                      4/28/20  4/29/20  4/30/20
# Country/Region
# Afghanistan               58       60       64
# Albania                   30       30       31
# Algeria                  437      444      450
# Andorra                   41       42       42
# Angola                     2        2        2
# Antigua and Barbuda        3        3        3
# Argentina                207      214      218
# Armenia                   30       30       32
# Australia                 89       91       93
# Austria                  569      580      584
#
# [10 rows x 100 columns]

# %% [markdown]
# ### Analyze the death rate for India and china

# %%
death_aggregation.loc["India"].plot()
death_aggregation.loc["China"].plot()
plt.legend()

# %%
countries = list(death_aggregation.index)
max_death_rate = []
for i in countries:
    max_death_rate.append(death_aggregation.loc[i].diff().max())
death_aggregation["max_death_rate"] = max_death_rate

# %%
death_aggregation.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        0        0
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20       ...        \
# Country/Region                                                ...
# Afghanistan                0        0        0        0       ...
# Albania                    0        0        0        0       ...
# Algeria                    0        0        0        0       ...
# Andorra                    0        0        0        0       ...
# Angola                     0        0        0        0       ...
# Antigua and Barbuda        0        0        0        0       ...
# Argentina                  0        0        0        0       ...
# Armenia                    0        0        0        0       ...
# Australia                  0        0        0        0       ...
# Austria                    0        0        0        0       ...
#
#                      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# Country/Region
# Afghanistan               40       42       43       47       50       57
# Albania                   27       27       27       27       28       28
# Algeria                  402      407      415      419      425      432
# Andorra                   37       37       40       40       40       40
# Angola                     2        2        2        2        2        2
# Antigua and Barbuda        3        3        3        3        3        3
# Argentina                152      165      176      185      192      197
# Armenia                   24       24       27       28       28       29
# Australia                 67       75       79       80       83       83
# Austria                  510      522      530      536      542      549
#
#                      4/28/20  4/29/20  4/30/20  max_death_rate
# Country/Region
# Afghanistan               58       60       64             7.0
# Albania                   30       30       31             4.0
# Algeria                  437      444      450            30.0
# Andorra                   41       42       42             4.0
# Angola                     2        2        2             2.0
# Antigua and Barbuda        3        3        3             1.0
# Argentina                207      214      218            13.0
# Armenia                   30       30       32             3.0
# Australia                 89       91       93             8.0
# Austria                  569      580      584            30.0
#
# [10 rows x 101 columns]

# %%
death_data = pd.DataFrame(death_aggregation["max_death_rate"])

# %%
death_data.head(10)
# Out:
#                      max_death_rate
# Country/Region
# Afghanistan                     7.0
# Albania                         4.0
# Algeria                        30.0
# Andorra                         4.0
# Angola                          2.0
# Antigua and Barbuda             1.0
# Argentina                      13.0
# Armenia                         3.0
# Australia                       8.0
# Austria                        30.0

# %% [markdown]
# ### Importing hapiness dataset

# %%
hapiness_data = pd.read_csv("worldwide_happiness_report.csv")

# %%
hapiness_data.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# 9                    1.016                         0.532       0.244
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
# 5                      0.343
# 6                      0.373
# 7                      0.380
# 8                      0.308
# 9                      0.226

# %%
col_to_drop = ["Overall rank", "Score","Generosity","Perceptions of corruption"]

# %%
hapiness_data.drop(col_to_drop,axis=1,inplace=True)
hapiness_data.head(10)
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
# 5       Switzerland           1.452           1.526                    1.052
# 6            Sweden           1.387           1.487                    1.009
# 7       New Zealand           1.303           1.557                    1.026
# 8            Canada           1.365           1.505                    1.039
# 9           Austria           1.376           1.475                    1.016
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557
# 5                         0.572
# 6                         0.574
# 7                         0.585
# 8                         0.584
# 9                         0.532

# %%
new_df = hapiness_data.set_index("Country or region")

# %% [markdown]
# # # Joining the hapiness data set and death dataset

# %%
dea_happ_data = new_df.join(death_data,how='inner')

# %%
new_df.head(10)
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
# Switzerland                 1.452           1.526                    1.052
# Sweden                      1.387           1.487                    1.009
# New Zealand                 1.303           1.557                    1.026
# Canada                      1.365           1.505                    1.039
# Austria                     1.376           1.475                    1.016
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557
# Switzerland                               0.572
# Sweden                                    0.574
# New Zealand                               0.585
# Canada                                    0.584
# Austria                                   0.532

# %% [markdown]
# ### Finding the corelation

# %%
dea_happ_data.corr()
# Out:
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.759468
# Social support                      0.759468        1.000000
# Healthy life expectancy             0.863062        0.765286
# Freedom to make life choices        0.394603        0.456246
# max_death_rate                      0.259893        0.204148
#
#                               Healthy life expectancy  \
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
# max_death_rate                               0.309666
#
#                               Freedom to make life choices  max_death_rate
# GDP per capita                                    0.394603        0.259893
# Social support                                    0.456246        0.204148
# Healthy life expectancy                           0.427892        0.309666
# Freedom to make life choices                      1.000000        0.080166
# max_death_rate                                    0.080166        1.000000

# %%
dea_happ_data.head(10)
# Out:
#              GDP per capita  Social support  Healthy life expectancy  \
# Finland               1.340           1.587                    0.986
# Denmark               1.383           1.573                    0.996
# Norway                1.488           1.582                    1.028
# Iceland               1.380           1.624                    1.026
# Netherlands           1.396           1.522                    0.999
# Switzerland           1.452           1.526                    1.052
# Sweden                1.387           1.487                    1.009
# New Zealand           1.303           1.557                    1.026
# Canada                1.365           1.505                    1.039
# Austria               1.376           1.475                    1.016
#
#              Freedom to make life choices  max_death_rate
# Finland                             0.596            43.0
# Denmark                             0.592            22.0
# Norway                              0.603            16.0
# Iceland                             0.591             5.0
# Netherlands                         0.557           234.0
# Switzerland                         0.572            75.0
# Sweden                              0.574           185.0
# New Zealand                         0.585             4.0
# Canada                              0.584           251.0
# Austria                             0.532            30.0

# %% [markdown]
# ## Visualizing

# %% [markdown]
# ### visualizing GDP per  capita vs  max_death_rate

# %%
x = dea_happ_data['GDP per capita']
y = dea_happ_data['max_death_rate']
sns.scatterplot(x,np.log(1+y))

# %%
sns.regplot(x, np.log(1+y))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### visualizing Social Support vs max_death_rate

# %%
x = dea_happ_data['Social support']
y = dea_happ_data['max_death_rate']
sns.scatterplot(x,np.log(1+y))

# %%
sns.regplot(x, np.log(1+y))

# %% [markdown]
# ### visualizing Healthy life expectancy	 vs max_death_rate

# %%
x = dea_happ_data['Healthy life expectancy']
y = dea_happ_data['max_death_rate']
sns.scatterplot(x,np.log(1+y))

# %%
sns.regplot(x, np.log(1+y))

# %% [markdown]
# ### Visualizing Freedom to make life choices vs max_death_rate

# %%
x = dea_happ_data['Freedom to make life choices']
y = dea_happ_data['max_death_rate']
sns.scatterplot(x,np.log(1+y))

# %%
sns.regplot(x, np.log(1+y))

# %% [markdown]
# # Importing covid confirmed dataset

# %%
cases = pd.read_csv('covid19_Confirmed_dataset.csv')

# %%
cases.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20   ...     4/21/20  \
# 0        0        0        0        0        0        0   ...        1092
# 1        0        0        0        0        0        0   ...         609
# 2        0        0        0        0        0        0   ...        2811
# 3        0        0        0        0        0        0   ...         717
# 4        0        0        0        0        0        0   ...          24
# 5        0        0        0        0        0        0   ...          23
# 6        0        0        0        0        0        0   ...        3031
# 7        0        0        0        0        0        0   ...        1401
# 8        0        0        0        0        0        0   ...         104
# 9        0        0        0        0        3        4   ...        2969
#
#    4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  \
# 0     1176     1279     1351     1463     1531     1703     1828     1939
# 1      634      663      678      712      726      736      750      766
# 2     2910     3007     3127     3256     3382     3517     3649     3848
# 3      723      723      731      738      738      743      743      743
# 4       25       25       25       25       26       27       27       27
# 5       24       24       24       24       24       24       24       24
# 6     3144     3435     3607     3780     3892     4003     4127     4285
# 7     1473     1523     1596     1677     1746     1808     1867     1932
# 8      104      104      105      106      106      106      106      106
# 9     2971     2976     2982     2994     3002     3004     3016     3016
#
#    4/30/20
# 0     2171
# 1      773
# 2     4006
# 3      745
# 4       27
# 5       24
# 6     4428
# 7     2066
# 8      106
# 9     3025
#
# [10 rows x 104 columns]

# %%
cases.drop(["Lat","Long"], axis = 1, inplace =True)
cases.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20   ...     4/21/20  \
# 0        0        0        0        0        0        0   ...        1092
# 1        0        0        0        0        0        0   ...         609
# 2        0        0        0        0        0        0   ...        2811
# 3        0        0        0        0        0        0   ...         717
# 4        0        0        0        0        0        0   ...          24
# 5        0        0        0        0        0        0   ...          23
# 6        0        0        0        0        0        0   ...        3031
# 7        0        0        0        0        0        0   ...        1401
# 8        0        0        0        0        0        0   ...         104
# 9        0        0        3        4        4        4   ...        2969
#
#    4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  \
# 0     1176     1279     1351     1463     1531     1703     1828     1939
# 1      634      663      678      712      726      736      750      766
# 2     2910     3007     3127     3256     3382     3517     3649     3848
# 3      723      723      731      738      738      743      743      743
# 4       25       25       25       25       26       27       27       27
# 5       24       24       24       24       24       24       24       24
# 6     3144     3435     3607     3780     3892     4003     4127     4285
# 7     1473     1523     1596     1677     1746     1808     1867     1932
# 8      104      104      105      106      106      106      106      106
# 9     2971     2976     2982     2994     3002     3004     3016     3016
#
#    4/30/20
# 0     2171
# 1      773
# 2     4006
# 3      745
# 4       27
# 5       24
# 6     4428
# 7     2066
# 8      106
# 9     3025
#
# [10 rows x 102 columns]

# %%
new_cases_df = cases.groupby('Country/Region').sum()
new_cases_df.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20   ...     4/21/20  \
# Country/Region                                            ...
# Afghanistan                0        0        0        0   ...        1092
# Albania                    0        0        0        0   ...         609
# Algeria                    0        0        0        0   ...        2811
# Andorra                    0        0        0        0   ...         717
# Angola                     0        0        0        0   ...          24
# Antigua and Barbuda        0        0        0        0   ...          23
# Argentina                  0        0        0        0   ...        3031
# Armenia                    0        0        0        0   ...        1401
# Australia                  5        6        9        9   ...        6645
# Austria                    0        0        0        0   ...       14873
#
#                      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# Country/Region
# Afghanistan             1176     1279     1351     1463     1531     1703
# Albania                  634      663      678      712      726      736
# Algeria                 2910     3007     3127     3256     3382     3517
# Andorra                  723      723      731      738      738      743
# Angola                    25       25       25       25       26       27
# Antigua and Barbuda       24       24       24       24       24       24
# Argentina               3144     3435     3607     3780     3892     4003
# Armenia                 1473     1523     1596     1677     1746     1808
# Australia               6652     6662     6677     6694     6714     6721
# Austria                14925    15002    15071    15148    15225    15274
#
#                      4/28/20  4/29/20  4/30/20
# Country/Region
# Afghanistan             1828     1939     2171
# Albania                  750      766      773
# Algeria                 3649     3848     4006
# Andorra                  743      743      745
# Angola                    27       27       27
# Antigua and Barbuda       24       24       24
# Argentina               4127     4285     4428
# Armenia                 1867     1932     2066
# Australia               6744     6752     6766
# Austria                15357    15402    15452
#
# [10 rows x 100 columns]

# %%
new_cases_df.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20   ...     4/21/20  \
# Country/Region                                            ...
# Afghanistan                0        0        0        0   ...        1092
# Albania                    0        0        0        0   ...         609
# Algeria                    0        0        0        0   ...        2811
# Andorra                    0        0        0        0   ...         717
# Angola                     0        0        0        0   ...          24
# Antigua and Barbuda        0        0        0        0   ...          23
# Argentina                  0        0        0        0   ...        3031
# Armenia                    0        0        0        0   ...        1401
# Australia                  5        6        9        9   ...        6645
# Austria                    0        0        0        0   ...       14873
#
#                      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# Country/Region
# Afghanistan             1176     1279     1351     1463     1531     1703
# Albania                  634      663      678      712      726      736
# Algeria                 2910     3007     3127     3256     3382     3517
# Andorra                  723      723      731      738      738      743
# Angola                    25       25       25       25       26       27
# Antigua and Barbuda       24       24       24       24       24       24
# Argentina               3144     3435     3607     3780     3892     4003
# Armenia                 1473     1523     1596     1677     1746     1808
# Australia               6652     6662     6677     6694     6714     6721
# Austria                14925    15002    15071    15148    15225    15274
#
#                      4/28/20  4/29/20  4/30/20
# Country/Region
# Afghanistan             1828     1939     2171
# Albania                  750      766      773
# Algeria                 3649     3848     4006
# Andorra                  743      743      745
# Angola                    27       27       27
# Antigua and Barbuda       24       24       24
# Argentina               4127     4285     4428
# Armenia                 1867     1932     2066
# Australia               6744     6752     6766
# Austria                15357    15402    15452
#
# [10 rows x 100 columns]

# %%
countries = list(new_cases_df.index)
max_confirmed_rate = []
for i in countries:
    max_confirmed_rate.append(new_cases_df.loc[i].diff().max())
new_cases_df["max_confirmed_rate"] = max_confirmed_rate

# %%
new_cases_df.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20         ...          \
# Country/Region                                                  ...
# Afghanistan                0        0        0        0         ...
# Albania                    0        0        0        0         ...
# Algeria                    0        0        0        0         ...
# Andorra                    0        0        0        0         ...
# Angola                     0        0        0        0         ...
# Antigua and Barbuda        0        0        0        0         ...
# Argentina                  0        0        0        0         ...
# Armenia                    0        0        0        0         ...
# Australia                  5        6        9        9         ...
# Austria                    0        0        0        0         ...
#
#                      4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# Country/Region
# Afghanistan             1176     1279     1351     1463     1531     1703
# Albania                  634      663      678      712      726      736
# Algeria                 2910     3007     3127     3256     3382     3517
# Andorra                  723      723      731      738      738      743
# Angola                    25       25       25       25       26       27
# Antigua and Barbuda       24       24       24       24       24       24
# Argentina               3144     3435     3607     3780     3892     4003
# Armenia                 1473     1523     1596     1677     1746     1808
# Australia               6652     6662     6677     6694     6714     6721
# Austria                14925    15002    15071    15148    15225    15274
#
#                      4/28/20  4/29/20  4/30/20  max_confirmed_rate
# Country/Region
# Afghanistan             1828     1939     2171               232.0
# Albania                  750      766      773                34.0
# Algeria                 3649     3848     4006               199.0
# Andorra                  743      743      745                43.0
# Angola                    27       27       27                 5.0
# Antigua and Barbuda       24       24       24                 6.0
# Argentina               4127     4285     4428               291.0
# Armenia                 1867     1932     2066               134.0
# Australia               6744     6752     6766               497.0
# Austria                15357    15402    15452              1321.0
#
# [10 rows x 101 columns]

# %%
dea_happ_data.head(1)
# Out:
#          GDP per capita  Social support  Healthy life expectancy  \
# Finland            1.34           1.587                    0.986
#
#          Freedom to make life choices  max_death_rate
# Finland                         0.596            43.0

# %%
new_cases_df=new_cases_df.join(dea_happ_data,how='inner')
new_cases_df.head(10)
# Out:
#              1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Afghanistan        0        0        0        0        0        0        0
# Albania            0        0        0        0        0        0        0
# Algeria            0        0        0        0        0        0        0
# Argentina          0        0        0        0        0        0        0
# Armenia            0        0        0        0        0        0        0
# Australia          0        0        0        0        4        5        5
# Austria            0        0        0        0        0        0        0
# Azerbaijan         0        0        0        0        0        0        0
# Bahrain            0        0        0        0        0        0        0
# Bangladesh         0        0        0        0        0        0        0
#
#              1/29/20  1/30/20  1/31/20       ...        4/27/20  4/28/20  \
# Afghanistan        0        0        0       ...           1703     1828
# Albania            0        0        0       ...            736      750
# Algeria            0        0        0       ...           3517     3649
# Argentina          0        0        0       ...           4003     4127
# Armenia            0        0        0       ...           1808     1867
# Australia          6        9        9       ...           6721     6744
# Austria            0        0        0       ...          15274    15357
# Azerbaijan         0        0        0       ...           1678     1717
# Bahrain            0        0        0       ...           2723     2811
# Bangladesh         0        0        0       ...           5913     6462
#
#              4/29/20  4/30/20  max_confirmed_rate  GDP per capita  \
# Afghanistan     1939     2171               232.0           0.350
# Albania          766      773                34.0           0.947
# Algeria         3848     4006               199.0           1.002
# Argentina       4285     4428               291.0           1.092
# Armenia         1932     2066               134.0           0.850
# Australia       6752     6766               497.0           1.372
# Austria        15402    15452              1321.0           1.376
# Azerbaijan      1766     1804               105.0           1.043
# Bahrain         2921     3040               301.0           1.362
# Bangladesh      7103     7667               641.0           0.562
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.517                    0.361
# Albania               0.848                    0.874
# Algeria               1.160                    0.785
# Argentina             1.432                    0.881
# Armenia               1.055                    0.815
# Australia             1.548                    1.036
# Austria               1.475                    1.016
# Azerbaijan            1.147                    0.769
# Bahrain               1.368                    0.871
# Bangladesh            0.928                    0.723
#
#              Freedom to make life choices  max_death_rate
# Afghanistan                         0.000             7.0
# Albania                             0.383             4.0
# Algeria                             0.086            30.0
# Argentina                           0.471            13.0
# Armenia                             0.283             3.0
# Australia                           0.557             8.0
# Austria                             0.532            30.0
# Azerbaijan                          0.351             3.0
# Bahrain                             0.536             1.0
# Bangladesh                          0.527            15.0
#
# [10 rows x 106 columns]

# %%
new_df = new_cases_df.iloc[:,-6:-1]
new_df['max_death_rate'] = new_cases_df['max_death_rate']
new_df.head(10)
# Out:
#              max_confirmed_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# Australia                 497.0           1.372           1.548
# Austria                  1321.0           1.376           1.475
# Azerbaijan                105.0           1.043           1.147
# Bahrain                   301.0           1.362           1.368
# Bangladesh                641.0           0.562           0.928
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
# Australia                      1.036                         0.557
# Austria                        1.016                         0.532
# Azerbaijan                     0.769                         0.351
# Bahrain                        0.871                         0.536
# Bangladesh                     0.723                         0.527
#
#              max_death_rate
# Afghanistan             7.0
# Albania                 4.0
# Algeria                30.0
# Argentina              13.0
# Armenia                 3.0
# Australia               8.0
# Austria                30.0
# Azerbaijan              3.0
# Bahrain                 1.0
# Bangladesh             15.0

# %% [markdown]
# ### Correlation

# %%
new_df.corr()
# Out:
#                               max_confirmed_rate  GDP per capita  \
# max_confirmed_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
# max_death_rate                          0.880597        0.259893
#
#                               Social support  Healthy life expectancy  \
# max_confirmed_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
# max_death_rate                      0.204148                 0.309666
#
#                               Freedom to make life choices  max_death_rate
# max_confirmed_rate                                0.078196        0.880597
# GDP per capita                                    0.394603        0.259893
# Social support                                    0.456246        0.204148
# Healthy life expectancy                           0.427892        0.309666
# Freedom to make life choices                      1.000000        0.080166
# max_death_rate                                    0.080166        1.000000

# %% [markdown]
# ### Visualizing

# %% [markdown]
# ### visualizing max_confirm_rate vs GDP per capita

# %%
y = new_df['max_confirmed_rate']
x = new_df['GDP per capita']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### visualizing max_confirm_rate vs Freedom to make life choices

# %%
y = new_df['max_confirmed_rate']
x = new_df['Freedom to make life choices']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# #### visualizing max_confirm_rate vs max_death_rate

# %%
x = new_df['max_confirmed_rate']
y = new_df['max_death_rate']

# %%
sns.scatterplot(np.log(1+x),np.log(1+y))

# %%
sns.regplot(np.log(1+x),np.log(1+y))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
